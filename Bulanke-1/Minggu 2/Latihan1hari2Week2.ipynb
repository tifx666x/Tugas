# %%
import tkinter as tk #mengimport library untuk applikasi GUI

def latihan_1():
    root = tk.Tk()    #membuat objek jendela tk dengan nama root
    root.title ("Latihan 1: Jendela Sederhana") #menambahkan caption ke dalam form
    root.mainloop() #form dijalankan

latihan_1()

# %%
import tkinter as tk
def latihan_2():
    root = tk.Tk()
    root.title ("Latihan 2: Menampilkan Label")
    label = tk.Label(root, text="Hello, ini adalah label", font=("Arial", 14))
    label.pack(pady=20)
    # Menjalankan loop utama
    root.mainloop()
    
latihan_2()

# %%
import tkinter as tk

def latihan_3():
    root = tk.Tk()
    root.title("Latihan 3: Tombol Klik")
    
    label = tk.Label(root, text="Klik tombol di bawah")
    label.pack()

    # Fungsi untuk mengubah teks label saat tombol diklik
    def ganti_teks():
        label.config(text="Tombol Sudah Diklik")

    # Membuat tombol di luar fungsi ganti_teks
    tombol = tk.Button(root, text="Klik Saya", command=ganti_teks)
    tombol.pack()

    root.mainloop()

latihan_3()

# %%
import tkinter as tk

def latihan_4():
    root = tk.Tk()
    root.title("Latihan 4: Input Pengguna")
    
    # Label dan Entry untuk memasukkan nama
    label = tk.Label(root, text="Masukkan Nama: ")
    label.pack()
    
    entry = tk.Entry(root)
    entry.pack()
    
    # Fungsi untuk menampilkan nama
    def tampilkan_nama():
        nama = entry.get()  # Mengambil teks dari Entry
        hasil.config(text=f"Halo, {nama}!")  # Mengubah teks di label hasil
    
    # Tombol untuk menampilkan nama
    tombol = tk.Button(root, text="Tampilkan Nama", command=tampilkan_nama)
    tombol.pack()
    
    # Label untuk menampilkan hasil
    hasil = tk.Label(root, text="")
    hasil.pack()
    
    root.mainloop()

latihan_4()

# %%
import tkinter as tk

def latihan_5():
    root = tk.Tk()
    root.title("Latihan 5: Radio Button")
    
    # Variabel untuk menyimpan pilihan
    pilihan = tk.StringVar(value="")
    
    # Fungsi untuk menampilkan pilihan
    def tampilkan_pilihan():
        hasil.config(text=f"Kamu memilih: {pilihan.get()}")
    
    # Radio Button 1
    rb1 = tk.Radiobutton(root, text="Pilihan 1", variable=pilihan, value="Pilihan 1", command=tampilkan_pilihan)
    rb1.pack()
    
    # Radio Button 2
    rb2 = tk.Radiobutton(root, text="Pilihan 2", variable=pilihan, value="Pilihan 2", command=tampilkan_pilihan)
    rb2.pack()
    
    # Label untuk menampilkan hasil pilihan
    hasil = tk.Label(root, text="")
    hasil.pack()
    
    root.mainloop()

latihan_5()

# %%
import tkinter as tk

def latihan_6():
    root = tk.Tk()
    root.title("Latihan 6: Checkbox")
    
    var1 = tk.IntVar()
    var2 = tk.IntVar()
    
    # Fungsi untuk mengecek pilihan dan menampilkan hasil
    def cek_pilihan():
        hasil = "Kamu Memilih: "
        if var1.get():
            hasil += "Pilihan 1 "
        if var2.get():
            hasil += "Pilihan 2 "
        label_hasil.config(text=hasil)
    
    # Checkbox untuk pilihan 1
    cb1 = tk.Checkbutton(root, text="Pilihan 1", variable=var1, command=cek_pilihan)
    cb1.pack()
    
    # Checkbox untuk pilihan 2
    cb2 = tk.Checkbutton(root, text="Pilihan 2", variable=var2, command=cek_pilihan)
    cb2.pack()
    
    # Label untuk menampilkan hasil
    label_hasil = tk.Label(root, text="")
    label_hasil.pack()
    
    root.mainloop()

latihan_6()

# %%
def latihan_7():
    root = tk.Tk()
    root.title ("Latihan 7: Kalkulator Penjumlahan")
    def hitung():
        angka1 = float(entry1.get())
        angka2 = float(entry2.get())
        hasil = angka1 + angka2
        label_hasil.config (text = f"Hasil: {hasil}")
    tk.Label(root, text = "Angka 1:").pack()
    entry1 = tk.Entry(root)
    entry1.pack()
    tk.Label(root, text = "Angka 2:").pack()
    entry2 = tk.Entry(root)
    entry2.pack()
    tombol_hitung = tk.Button(root, text="Hitung", command = hitung)
    tombol_hitung.pack()
    label_hasil= tk.Label(root, text = "Hasil: ")
    label_hasil.pack()
    root.mainloop()

latihan_7()

# %%
import tkinter as tk

def latihan_volume_balok():
    root = tk.Tk()
    root.title("Latihan: Kalkulator Volume Balok")
    

    def hitung_volume():
            panjang = float(entry_panjang.get())
            lebar = float(entry_lebar.get())
            tinggi = float(entry_tinggi.get())
            volume = panjang * lebar * tinggi
            label_hasil.config(text=f"Volume Balok: {volume} m³")


    tk.Label(root, text="Panjang (m):").pack()
    entry_panjang = tk.Entry(root)
    entry_panjang.pack()


    tk.Label(root, text="Lebar (m):").pack()
    entry_lebar = tk.Entry(root)
    entry_lebar.pack()


    tk.Label(root, text="Tinggi (m):").pack()
    entry_tinggi = tk.Entry(root)
    entry_tinggi.pack()


    tombol_hitung = tk.Button(root, text="Hitung Volume", command=hitung_volume)
    tombol_hitung.pack()

    # Label untuk menampilkan hasil
    label_hasil = tk.Label(root, text="Volume Balok: ")
    label_hasil.pack()

    root.mainloop()

latihan_volume_balok()

# %%
import tkinter as tk

def latihan_bilangan_prima():
    root = tk.Tk()
    root.title("Latihan: Cek Bilangan Prima")
    
    # Fungsi untuk mengecek apakah bilangan prima
    def cek_prima():
        try:
            angka = int(entry_angka.get())
            if angka > 1:
                for i in range(2, angka):
                    if angka % i == 0:
                        label_hasil.config(text=f"{angka} bukan bilangan prima.")
                        break
                else:
                    label_hasil.config(text=f"{angka} adalah bilangan prima.")
            else:
                label_hasil.config(text=f"{angka} bukan bilangan prima.")
        except ValueError:
            label_hasil.config(text="Input tidak valid, masukkan angka.")

    # Input untuk angka yang ingin diperiksa
    tk.Label(root, text="Masukkan Angka:").pack()
    entry_angka = tk.Entry(root)
    entry_angka.pack()

    # Tombol untuk cek prima
    tombol_cek = tk.Button(root, text="Cek Bilangan Prima", command=cek_prima)
    tombol_cek.pack()

    # Label untuk menampilkan hasil
    label_hasil = tk.Label(root, text="Hasil: ")
    label_hasil.pack()

    root.mainloop()

latihan_bilangan_prima()

# %%
def latihan_8():
    root = tk.Tk()
    root.title ("Latihan 8: Listbox")
    listbox = tk.Listbox(root)
    listbox.insert(1, "Pilihan 1")
    listbox.insert(2, "Pilihan 2")
    listbox.insert(3, "Pilihan 3")
    listbox.pack()
    def pilih():
        pilihan = listbox.get(listbox.curselection())
        label_pilihan.config(text=f"Kamu Memilih: {pilihan}")
    tombol = tk.Button(root,text="Pilih", command=pilih)
    tombol.pack()
    label_pilihan = tk.Label(root, text= "")
    label_pilihan.pack()
    root.mainloop()

latihan_8()

# %%
def latihan_9():
    root = tk.Tk()
    root.title("Latihan 9: Skala")
    def update_value(value):
        label_value.config(text=f"Nilai: {value}")

    scale = tk.Scale(root, from_=0, to = 100, orient=tk.HORIZONTAL, command=update_value)
    scale.pack()

    label_value = tk.Label (root, text = "Nilai: 0")
    label_value.pack()

    root.mainloop()

latihan_9()

# %%
import tkinter as tk
from tkinter import ttk

def latihan_10():
    root = tk.Tk()
    root.title("Latihan 10: Tabel Data")

    tree = ttk.Treeview(root, columns=("Nama", "Umur", "Kota"), show='headings')

    tree.heading("Nama", text="Nama")
    tree.heading("Umur", text="Umur")
    tree.heading("Kota", text="Kota")

    data = [
        ("Budi", 25, "Jakarta"),
        ("Susi", 30, "Bandung"),
        ("Andi", 22, "Surabaya"),
    ]
    
    for row in data:
        tree.insert("", tk.END, values=row)

    tree.pack()

    root.mainloop()

latihan_10()

# %%
import tkinter as tk

def latihan_11():
    root = tk.Tk()
    root.title("Latihan 11: To-Do List")

    # Daftar untuk menyimpan tugas
    tasks = []

    def tambah_tugas():
        tugas = entry_tugas.get()
        if tugas:
            tasks.append(tugas)
            update_listbox()
            entry_tugas.delete(0, tk.END)

    def hapus_tugas():
        selected_task = listbox_tugas.curselection()
        if selected_task:
            tasks.pop(selected_task[0])
            update_listbox()

    def update_listbox():
        listbox_tugas.delete(0, tk.END)
        for task in tasks:
            listbox_tugas.insert(tk.END, task)


    entry_tugas = tk.Entry(root)
    entry_tugas.pack()

    tombol_tambah = tk.Button(root, text="Tambah Tugas", command=tambah_tugas)
    tombol_tambah.pack()

    tombol_hapus = tk.Button(root, text="Hapus Tugas", command=hapus_tugas)
    tombol_hapus.pack()

    listbox_tugas = tk.Listbox(root)
    listbox_tugas.pack()

    root.mainloop()

latihan_11()

# %%
import tkinter as tk
from tkinter import messagebox

def latihan_13():
    root = tk.Tk()
    root.title("Latihan 13: Buku Telepon")

    kontak = []

    def tambah_kontak():
        nama = entry_nama.get()
        nomor = entry_nomor.get()
        if nama and nomor:
            kontak.append((nama, nomor))
            update_listbox()
            entry_nama.delete(0, tk.END)
            entry_nomor.delete(0, tk.END)
        else:
            messagebox.showwarning("Input Error", "Nama dan Nomor harus diisi!")

    def hapus_kontak():
        selected_index = listbox_kontak.curselection()
        if selected_index:
            kontak.pop(selected_index[0])
            update_listbox()
        else:
            messagebox.showwarning("Pilih Kontak", "Pilih kontak yang akan dihapus!")

    def update_listbox():
        listbox_kontak.delete(0, tk.END)
        for nama, nomor in kontak:
            listbox_kontak.insert(tk.END, f"{nama} - {nomor}")

    tk.Label(root, text="Nama:").pack()
    entry_nama = tk.Entry(root)
    entry_nama.pack()

    tk.Label(root, text="Nomor Telepon:").pack()
    entry_nomor = tk.Entry(root)
    entry_nomor.pack()

    tombol_tambah = tk.Button(root, text="Tambah Kontak", command=tambah_kontak)
    tombol_tambah.pack()

    tombol_hapus = tk.Button(root, text="Hapus Kontak", command=hapus_kontak)
    tombol_hapus.pack()

    listbox_kontak = tk.Listbox(root)
    listbox_kontak.pack()

    root.mainloop()

latihan_13()
